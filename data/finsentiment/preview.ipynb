# %%
from utils import ds

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'source'],
#         num_rows: 80029
#     })
#     test: Dataset({
#         features: ['text', 'label', 'source'],
#         num_rows: 10004
#     })
#     valid: Dataset({
#         features: ['text', 'label', 'source'],
#         num_rows: 10004
#     })
# })

# %%
ds["train"]
# Out:
# Dataset({
#     features: ['text', 'label', 'source'],
#     num_rows: 80029
# })

# %%
import pandas as pd


a = pd.DataFrame(ds["train"])

# %%
a["label"].value_counts()
# Out:
# label
# 1    40957
# 2    22050
# 0    17022
# Name: count, dtype: int64

# %%
a["text"]
# Out:
# 0        Fed's Rosengren says he is 'optimistic' on eco...
# 1        LAS VEGAS, NV / ACCESSWIRE / March 23, 2021 / ...
# 2        $AAPL weekly still under the 50 moving average...
# 3        Mass layoffs push Canada consumer confidence t...
# 4        Silver Price Forecast – Silver Markets Continu...
#                                ...
# 80024    This bold spinning 360 red fabric design is se...
# 80025    user: XOM - target 89.50 - mkt goes red big to...
# 80026    In the third quarter , net sales increased by ...
# 80027    @DivesTech Great calls this week on $AAPL, $MS...
# 80028    #Tesla Model S deliveries are up 35% in German...
# Name: text, Length: 80029, dtype: object

# %%
length = [len(txt)for txt in a["text"]]
max(length), min(length)
# Out:
# (4229, 1)

# %%
import torch
torch.quantile(torch.as_tensor(length, dtype=torch.float), 0.99)
# Out:
# tensor(330.)

# %%
ds["valid"]
# Out:
# Dataset({
#     features: ['text', 'label', 'source'],
#     num_rows: 10004
# })

# %%
import torch

m = torch.nn.AdaptiveAvgPool2d((5, 7))
i = torch.randn(1, 64, 8, 9)
output = m(i)

# %%
output.shape
# Out:
# torch.Size([1, 64, 5, 7])
